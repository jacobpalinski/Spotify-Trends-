# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import requests

# %%
#Token / Ids
url='https://accounts.spotify.com/api/token'
client_id='39c58ce155a94f008ad14229d8447ef7'
client_secret='c03dc70737814e6cb7f887e50db315ed'

# %%
auth_response=requests.post(url, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    
})

# %%
auth_response_data=auth_response.json()
access_token=auth_response_data['access_token']
print(access_token)
# Out:
# BQC7ZJYSLi80NE3l8JyxVzq9b4cKh4a84WjTtkIlq6tNOBqjI-q7vInG7VD_tJZlno9V0vt0w99Q3Zev4FQ

# %%
headers={'Authorization': 'Bearer {}'.format(access_token)}

# %%
#Rock Top 1000
playlists_url='https://api.spotify.com/v1/playlists/'
playlists_id='7KMtxb9kh3TtVvJTdLtJ2K'
playlist_rock=requests.get(playlists_url+playlists_id+'/tracks',headers=headers)

#Trance Top 1000
playlists_id1='4BJbcyG5JosaXGyucqOyI7'
playlist_trance=requests.get(playlists_url+playlists_id1+ '/tracks',headers=headers)

#Top 1000 Hip Hop Rap
playlists_id2='5AVEP6Z2kNCo1ZHShutXbT'
playlist_rap=requests.get(playlists_url+playlists_id2+'/tracks',headers=headers)

# Top 1000 Pop
playlists_id3='23HsgHgvpjludlObYNpA1S'
playlists_pop=requests.get(playlists_url+ playlists_id3+'/tracks',headers=headers)

#R&B Top 1000
playlists_id4='7CI3NR7rvCkgiLhch1qprf'
playlists_rb=requests.get(playlists_url+playlists_id3+'/tracks',headers=headers)

# %%
import json
playlistrock_json=playlist_rock.json()
with open('playlistrock_json','w') as f:
    json.dump(playlistrock_json,f)

rockdf=pd.read_json('playlistrock_json')
rockdf['items'][1]
# Out:
# {'added_at': '2019-05-14T15:11:28Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frequencine'},
#   'href': 'https://api.spotify.com/v1/users/frequencine',
#   'id': 'frequencine',
#   'type': 'user',
#   'uri': 'spotify:user:frequencine'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#      'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#      'id': '58lV9VcRSjABbAbfWS6skp',
#      'name': 'Bon Jovi',
#      'type': 'artist',
#      'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
# ...
