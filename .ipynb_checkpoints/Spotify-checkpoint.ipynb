# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import requests

# %%
#Token / Ids
url='https://accounts.spotify.com/api/token'
client_id='39c58ce155a94f008ad14229d8447ef7'
client_secret='c03dc70737814e6cb7f887e50db315ed'

# %%
auth_response=requests.post(url, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    
})

# %%
auth_response_data=auth_response.json()
access_token=auth_response_data['access_token']
print(access_token)
# Out:
# BQAaM83PvjrEp85Cwd57-MVbxRN2nZwqO-L-l7YpJNyRgdHJKtfxrhsmLOUCCVQP7dSPONLv9WPNpgeXbz4

# %%
headers={'Authorization': 'Bearer {}'.format(access_token)}

# %%
#Rock Top 1000
playlists_url='https://api.spotify.com/v1/playlists/'
playlists_id='7KMtxb9kh3TtVvJTdLtJ2K'
playlist_rock=requests.get(playlists_url+playlists_id,headers=headers)

#Trance Top 1000
playlists_id1='4BJbcyG5JosaXGyucqOyI7'
playlist_trance=requests.get(playlists_url+playlists_id1,headers=headers)

#Top 1000 Hip Hop Rap
playlists_id2='5AVEP6Z2kNCo1ZHShutXbT'
playlist_rap=requests.get(playlists_url+playlists_id2,headers=headers)

# %%
playlist_rock.json()
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/7KMtxb9kh3TtVvJTdLtJ2K'},
#  'followers': {'href': None, 'total': 518},
#  'href': 'https://api.spotify.com/v1/playlists/7KMtxb9kh3TtVvJTdLtJ2K',
#  'id': '7KMtxb9kh3TtVvJTdLtJ2K',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731336b31b6a1799f0de5807acab67616d0000b27321ebf49b3292c3f0f575f0f5ab67616d0000b2738fc4b0dcfb9509553f195c85ab67616d0000b2739a81658775e67d37b9e13be1',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731336b31b6a1799f0de5807acab67616d0000b27321ebf49b3292c3f0f575f0f5ab67616d0000b2738fc4b0dcfb9509553f195c85ab67616d0000b2739a81658775e67d37b9e13be1',
#    'width': 300},
#   {'height': 60,
# ...

# %%
playlists_url
